# %%
import pandas as pd
import os
import subprocess
from typing import List, Dict, Tuple
import calplot
import matplotlib.colors as mcolors
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
path = r"C:\Users\michw\IoT\data\output.parquet"

df = pd.read_parquet(path)
df = df.drop(columns=['snr', 'WIFI', 'BLE', 'rssi', 'channel_rssi', 'gateway', 'channel_index', 'spreading_factor', 'bandwidth', 'f_cnt'])
print(df)
# Out:
#                  date_time     device_id    tmp    hum  CO2   VOC  vis  IR  \
# 0      2023-03-18 00:13:10  hka-aqm-n214  19.80  38.14  424  1032    6   0
# 1      2023-03-18 00:28:19  hka-aqm-n214  19.80  38.18  423   999    6   0
# 2      2023-03-18 00:43:25  hka-aqm-n214  19.80  38.18  423   970    6   0
# 3      2023-03-18 00:58:31  hka-aqm-n214  19.78  38.24  417   817    6   2
# 4      2023-03-18 01:13:38  hka-aqm-n214  19.81  38.31  426   883    6   0
# ...                    ...           ...    ...    ...  ...   ...  ...  ..
# 282015 2023-04-15 20:43:02  hka-aqm-n113  20.90  42.05  421  1026    5   0
# 282016 2023-04-15 21:29:16  hka-aqm-n113  20.88  42.57  425  1152    7   2
# 282017 2023-04-15 22:30:29  hka-aqm-n113  20.84  42.18  430  1342    5   0
# 282018 2023-04-15 23:01:16  hka-aqm-n113  20.83  42.57  434  1266    7   2
# 282019 2023-04-15 23:16:36  hka-aqm-n113  20.81  42.77  428  1420    5   0
#
#        room  floor
# 0       214      2
# 1       214      2
# 2       214      2
# 3       214      2
# 4       214      2
# ...     ...    ...
# 282015  113      1
# 282016  113      1
# 282017  113      1
# 282018  113      1
# 282019  113      1
#
# [282020 rows x 10 columns]

# %% [markdown]
# ---

# %%
temps_floor2_2022 = df[(df['floor'] == 2) & (df['date_time'].dt.year == 2022)]
numeric_df_2022 = temps_floor2_2022.select_dtypes(include=[np.number])
numeric_df_2022['date_time'] = temps_floor2_2022['date_time']
daily_avg_temp_2022 = numeric_df_2022.resample('D', on='date_time').mean().reset_index()

# %%
fig = px.line(daily_avg_temp_2022, x='date_time', y='tmp', title='Täglicher Durchschnitt der Temperatur im Jahr 2022',
              labels={'date_time': 'Datum', 'tmp': 'Durchschnittliche Temperatur (°C)'})

fig.show()

# %%
temps_floor2_2023 = df[(df['floor'] == 2) & (df['date_time'].dt.year == 2023)]
numeric_df_2023 = temps_floor2_2023.select_dtypes(include=[np.number])
numeric_df_2023['date_time'] = temps_floor2_2023['date_time']
daily_avg_temp_2023 = numeric_df_2023.resample('D', on='date_time').mean().reset_index()

# %%
fig = px.line(daily_avg_temp_2023, x='date_time', y='tmp', title='Täglicher Durchschnitt der Temperatur im Jahr 2023',
              labels={'date_time': 'Datum', 'tmp': 'Durchschnittliche Temperatur (°C)'})

fig.show()

# %% [markdown]
# ---

# %%
hum_floor2_2022 = df[(df['floor'] == 2) & (df['date_time'].dt.year == 2022)]
numeric_df_2022 = temps_floor2_2022.select_dtypes(include=[np.number])
numeric_df_2022['date_time'] = hum_floor2_2022['date_time']
daily_avg_hum_2022 = numeric_df_2022.resample('D', on='date_time').mean().reset_index()

# %%
fig = px.line(daily_avg_hum_2022, x='date_time', y='hum', title='Täglicher Durchschnitt der Luftfeuchtigkeit im Jahr 2022',
              labels={'date_time': 'Datum', 'hum': 'Durchschnittliche Luftfeuchtigkeit'})

fig.show()

# %%
hum_floor2_2023 = df[(df['floor'] == 2) & (df['date_time'].dt.year == 2023)]
numeric_df_2023 = hum_floor2_2023.select_dtypes(include=[np.number])
numeric_df_2023['date_time'] = hum_floor2_2023['date_time']
daily_avg_hum_2023 = numeric_df_2023.resample('D', on='date_time').mean().reset_index()

# %%
fig = px.line(daily_avg_hum_2023, x='date_time', y='hum', title='Täglicher Durchschnitt der Luftfeuchtigkeit im Jahr 2023',
              labels={'date_time': 'Datum', 'hum': 'Durchschnittliche Luftfeuchtigkeit'})

fig.show()

# %% [markdown]
# ---

# %%
co2_floor2_2022 = df[(df['floor'] == 2) & (df['date_time'].dt.year == 2022)]
numeric_df_2022 = co2_floor2_2022.select_dtypes(include=[np.number])
numeric_df_2022['date_time'] = co2_floor2_2022['date_time']
daily_avg_co2_2022 = numeric_df_2022.resample('D', on='date_time').mean().reset_index()

# %%
fig = px.line(daily_avg_co2_2022, x='date_time', y='CO2', title='Täglicher Durchschnitt des CO2 Wert im Jahr 2023',
              labels={'date_time': 'Datum', 'CO2': 'Durchschnittlich CO2'})

fig.show()

# %%
co2_floor2_2023 = df[(df['floor'] == 2) & (df['date_time'].dt.year == 2023)]
numeric_df_2023 = co2_floor2_2023.select_dtypes(include=[np.number])
numeric_df_2023['date_time'] = co2_floor2_2023['date_time']
daily_avg_co2_2023 = numeric_df_2023.resample('D', on='date_time').mean().reset_index()

# %%
fig = px.line(daily_avg_co2_2023, x='date_time', y='CO2', title='Täglicher Durchschnitt des CO2 Wert im Jahr 2023',
              labels={'date_time': 'Datum', 'CO2': 'Durchschnittlich CO2'})

fig.show()

# %% [markdown]
# ---

# %%
voc_floor2_2022 = df[(df['floor'] == 2) & (df['date_time'].dt.year == 2022)]
numeric_df_2022 = voc_floor2_2022.select_dtypes(include=[np.number])
numeric_df_2022['date_time'] = voc_floor2_2022['date_time']
daily_avg_voc_2022 = numeric_df_2022.resample('D', on='date_time').mean().reset_index()

# %%
fig = px.line(daily_avg_voc_2022, x='date_time', y='VOC', title='Täglicher Durchschnitt des VOC Wert im Jahr 2022',
              labels={'date_time': 'Datum', 'VOC': 'Durchschnittlich VOC'})

fig.show()

# %%
voc_floor2_2023 = df[(df['floor'] == 2) & (df['date_time'].dt.year == 2023)]
numeric_df_2023 = voc_floor2_2023.select_dtypes(include=[np.number])
numeric_df_2023['date_time'] = voc_floor2_2023['date_time']
daily_avg_voc_2023 = numeric_df_2023.resample('D', on='date_time').mean().reset_index()

# %%
fig = px.line(daily_avg_voc_2023, x='date_time', y='VOC', title='Täglicher Durchschnitt des VOC Wert im Jahr 2023',
              labels={'date_time': 'Datum', 'VOC': 'Durchschnittlich VOC'})

fig.show()

# %% [markdown]
# ---

# %%
vis_floor2_2022 = df[(df['floor'] == 2) & (df['date_time'].dt.year == 2022)]
numeric_df_2022 = vis_floor2_2022.select_dtypes(include=[np.number])
numeric_df_2022['date_time'] = vis_floor2_2022['date_time']
daily_avg_vis_2022 = numeric_df_2022.resample('D', on='date_time').mean().reset_index()

# %%
fig = px.line(daily_avg_vis_2022, x='date_time', y='vis', title='Täglicher Durchschnitt des vic Wert im Jahr 2022',
              labels={'date_time': 'Datum', 'vis': 'Durchschnittlich vis'})

fig.show()

# %%
vis_floor2_2023 = df[(df['floor'] == 2) & (df['date_time'].dt.year == 2023)]
numeric_df_2022 = vis_floor2_2022.select_dtypes(include=[np.number])
numeric_df_2023['date_time'] = vis_floor2_2023['date_time']
daily_avg_vis_2023 = numeric_df_2023.resample('D', on='date_time').mean().reset_index()

# %%
fig = px.line(daily_avg_vis_2023, x='date_time', y='vis', title='Täglicher Durchschnitt des vic Wert im Jahr 2023',
              labels={'date_time': 'Datum', 'vis': 'Durchschnittlich vis'})

fig.show()

# %% [markdown]
# ---

# %%
ir_floor2_2022 = df[(df['floor'] == 2) & (df['date_time'].dt.year == 2022)]
numeric_df_2022 = ir_floor2_2022.select_dtypes(include=[np.number])
numeric_df_2022['date_time'] = ir_floor2_2022['date_time']
daily_avg_ir_2022 = numeric_df_2022.resample('D', on='date_time').mean().reset_index()

# %%
fig = px.line(daily_avg_ir_2022, x='date_time', y='IR', title='Täglicher Durchschnitt des IR Wert im Jahr 2022',
              labels={'date_time': 'Datum', 'vis': 'Durchschnittlich IR'})

fig.show()

# %%
ir_floor2_2023 = df[(df['floor'] == 2) & (df['date_time'].dt.year == 2023)]
numeric_df_2023 = ir_floor2_2023.select_dtypes(include=[np.number])
numeric_df_2023['date_time'] = ir_floor2_2023['date_time']
daily_avg_ir_2023 = numeric_df_2023.resample('D', on='date_time').mean().reset_index()

# %%
fig = px.line(daily_avg_ir_2023, x='date_time', y='IR', title='Täglicher Durchschnitt des IR Wert im Jahr 2022',
              labels={'date_time': 'Datum', 'vis': 'Durchschnittlich IR'})

fig.show()
